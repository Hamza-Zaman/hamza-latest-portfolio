# %% [markdown]
# # My Screen Time Dashboard Analysis

# %% [markdown]
# ```
# The data contains the following fields:
#
# ```
# 1. date : Date
# 2. week_number: Number of Week
# 3. facebook: Hours spent on Facebook
# 4. whatsapp: Hours spent on WhatsApp
# 5. youtube: Hours spent on Youtube
# 6. linkedin: Hours spent on Linkedin
# 7. gmail: Hours spent on Linkedin
# 8. adobe_acrobat: Hours spent on Adobe Acrobat
# 9. binance: Hours spent on Binance
# 10. samsung_internet: Hours spent on Samsung Internet
# 11. twitter: Hours spent on Twitter
# 12. notifications: Total notifications per day
# 13. screen_time: Total Screen Time per day
# 14. most_notifications_app: Most notification by an app per day

# %% [markdown]
# **TechStack:**
# * Numpy
# *  Pandas
# *  Matplotlib
# *  Seaborn

# %% [markdown]
# #### 👉 Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 👉 Analyzing the data

# %%
df = pd.read_csv("screentime_analysis.csv")
df.head()
# Out:
#        date  week_number  facebook  whatsapp  youtube  linkedin  gmail  \
# 0  1-Jun-22           22      1.47      0.37     0.00      1.08   0.07
# 1  2-Jun-22           22      2.03      0.05     0.15      1.10   0.00
# 2  3-Jun-22           22      1.65      0.17     0.00      1.50   0.03
# 3  4-Jun-22           22      1.23      0.13     0.02      0.45   0.02
# 4  5-Jun-22           22      0.40      0.07     0.00      1.10   0.00
#
#    adobe_acrobat  binance  samsung_internet  twitter  notifications  \
# 0            0.0     0.03              0.18     0.08            240
# 1            0.0     0.00              0.23     0.47            194
# 2            0.0     0.03              0.20     0.20            226
# 3            0.0     0.02              0.03     0.05            175
# 4            0.0     0.00              0.27     0.28            266
#
#    screen_time most_notifications_app
# 0         3.80               linkedin
# 1         4.18               linkedin
# ...

# %%
df.tail()
# Out:
#          date  week_number  facebook  whatsapp  youtube  linkedin  gmail  \
# 16  17-Jun-22           24      0.68      0.18     0.00      1.45   0.05
# 17  18-Jun-22           24      1.47      0.25     0.02      2.18   0.07
# 18  19-Jun-22           24      2.00      1.42     0.52      1.12   0.22
# 19  20-Jun-22           24      2.75      1.60     1.28      1.07   0.03
# 20  21-Jun-22           24      2.05      0.62     1.03      1.83   0.08
#
#     adobe_acrobat  binance  samsung_internet  twitter  notifications  \
# 16            0.0     0.00              0.10     0.38            160
# 17            0.0     0.00              0.30     0.22            253
# 18            0.0     0.02              0.07     0.32            286
# 19            0.0     0.02              0.02     0.05            391
# 20            0.0     0.00              0.40     1.18            318
#
#     screen_time most_notifications_app
# 16         3.22               linkedin
# ...

# %%
df.shape
# Out:
# (21, 14)

# %%
df.columns
# Out:
# Index(['date', 'week_number', 'facebook', 'whatsapp', 'youtube', 'linkedin',
#        'gmail', 'adobe_acrobat', 'binance', 'samsung_internet', 'twitter',
#        'notifications', 'screen_time', 'most_notifications_app'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    21 non-null     object
#  1   week_number             21 non-null     int64
#  2   facebook                21 non-null     float64
#  3   whatsapp                21 non-null     float64
#  4   youtube                 21 non-null     float64
#  5   linkedin                21 non-null     float64
#  6   gmail                   21 non-null     float64
#  7   adobe_acrobat           21 non-null     float64
#  8   binance                 21 non-null     float64
#  9   samsung_internet        21 non-null     float64
#  10  twitter                 21 non-null     float64
#  11  notifications           21 non-null     int64
#  12  screen_time             21 non-null     float64
#  13  most_notifications_app  21 non-null     object
# ...

# %%
df.nunique()
# Out:
# date                      21
# week_number                3
# facebook                  19
# whatsapp                  19
# youtube                   10
# linkedin                  19
# gmail                      9
# adobe_acrobat              4
# binance                    4
# samsung_internet          18
# twitter                   15
# notifications             20
# screen_time               20
# most_notifications_app     3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# date                      0
# week_number               0
# facebook                  0
# whatsapp                  0
# youtube                   0
# linkedin                  0
# gmail                     0
# adobe_acrobat             0
# binance                   0
# samsung_internet          0
# twitter                   0
# notifications             0
# screen_time               0
# most_notifications_app    0
# dtype: int64

# %%
df.iloc[:,2:13].describe().round(2)
# Out:
#        facebook  whatsapp  youtube  linkedin  gmail  adobe_acrobat  binance  \
# count     21.00     21.00    21.00     21.00  21.00          21.00    21.00
# mean       1.26      0.45     0.18      1.36   0.06           0.01     0.02
# std        0.64      0.44     0.35      0.53   0.09           0.03     0.02
# min        0.40      0.05     0.00      0.45   0.00           0.00     0.00
# 25%        0.70      0.17     0.00      1.08   0.00           0.00     0.00
# 50%        1.23      0.30     0.02      1.13   0.03           0.00     0.02
# 75%        1.65      0.53     0.20      1.82   0.07           0.00     0.03
# max        2.75      1.60     1.28      2.33   0.35           0.13     0.05
#
#        samsung_internet  twitter  notifications  screen_time
# count             21.00    21.00          21.00        21.00
# mean               0.16     0.26         246.19         4.23
# std                0.13     0.25          60.65         1.58
# ...

# %% [markdown]
# ### 👉 Statistics of Social Media Apps

# %%
df_mean = df.iloc[:, 2:11].mean().round(2)
df_mean = df_mean.sort_values(ascending= False)
df_mean
# Out:
# linkedin            1.36
# facebook            1.26
# whatsapp            0.45
# twitter             0.26
# youtube             0.18
# samsung_internet    0.16
# gmail               0.06
# binance             0.02
# adobe_acrobat       0.01
# dtype: float64

# %%
df_mean= pd.DataFrame(df_mean)

# %%
df_mean= df_mean.reset_index()
df_mean.columns.values[0] = 'name'
df_mean.columns.values[1] = 'hours'
df_mean
# Out:
#                name  hours
# 0          linkedin   1.36
# 1          facebook   1.26
# 2          whatsapp   0.45
# 3           twitter   0.26
# 4           youtube   0.18
# 5  samsung_internet   0.16
# 6             gmail   0.06
# 7           binance   0.02
# 8     adobe_acrobat   0.01

# %%
df_median = df.iloc[:, 2:11].median().round(2)
df_median = df_median.sort_values(ascending= False)
df_median
# Out:
# facebook            1.23
# linkedin            1.13
# whatsapp            0.30
# twitter             0.20
# samsung_internet    0.12
# gmail               0.03
# youtube             0.02
# binance             0.02
# adobe_acrobat       0.00
# dtype: float64

# %%
df_median= pd.DataFrame(df_median)

# %%
df_median= df_median.reset_index()
df_median.columns.values[0] = 'name'
df_median.columns.values[1] = 'hours'
df_median
# Out:
#                name  hours
# 0          facebook   1.23
# 1          linkedin   1.13
# 2          whatsapp   0.30
# 3           twitter   0.20
# 4  samsung_internet   0.12
# 5             gmail   0.03
# 6           youtube   0.02
# 7           binance   0.02
# 8     adobe_acrobat   0.00

# %%
df.dtypes
# Out:
# date                       object
# week_number                 int64
# facebook                  float64
# whatsapp                  float64
# youtube                   float64
# linkedin                  float64
# gmail                     float64
# adobe_acrobat             float64
# binance                   float64
# samsung_internet          float64
# twitter                   float64
# notifications               int64
# screen_time               float64
# most_notifications_app     object
# dtype: object

# %%
screen_time_mean = df["screen_time"].mean()
screen_time_mean
# Out:
# 4.231428571428571

# %%
screen_time_median = df["screen_time"].median()
screen_time_median
# Out:
# 4.18

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(df_mean['name'], df_mean['hours'], color = ['c', 'c', 'g', 'g', 'g', 'g', 'g', 'g', 'g'],
        width = 0.4)
 
plt.xlabel("App Name")
plt.ylabel("Average number of hours")
plt.title("Average Hours Spent On Social Media Apps")
plt.tight_layout()
plt.savefig('Average Hours Spent On Social Media Apps.jpeg', dpi = 300,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Visualizing the data

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(df_median['name'], df_median['hours'], color = ['c', 'c', 'g', 'g', 'g', 'g', 'g', 'g', 'g'],
        width = 0.4)
 
plt.xlabel("App Name")
plt.ylabel("Median number of hours")
plt.title("Median Hours Spent On Social Media Apps")
plt.tight_layout()
plt.savefig('Median Hours Spent On Social Media Apps.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
colors = ["green" if i > 4 else "maroon" for i in df['screen_time']]
ax =plt.bar(df['date'], df['screen_time'], color = colors,
        width = 0.4)

plt.xticks(rotation=45, fontweight='medium',  fontsize='medium')

plt.xlabel("Date")
plt.ylabel("Number of hours")
plt.title("Screen time per day")
plt.ylim(0,9)
plt.tight_layout()
plt.savefig('Screen time per day.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
week_22 = df.iloc[0:7, :]
week_22
# Out:
#        date  week_number  facebook  whatsapp  youtube  linkedin  gmail  \
# 0  1-Jun-22           22      1.47      0.37     0.00      1.08   0.07
# 1  2-Jun-22           22      2.03      0.05     0.15      1.10   0.00
# 2  3-Jun-22           22      1.65      0.17     0.00      1.50   0.03
# 3  4-Jun-22           22      1.23      0.13     0.02      0.45   0.02
# 4  5-Jun-22           22      0.40      0.07     0.00      1.10   0.00
# 5  6-Jun-22           22      0.85      0.10     0.00      1.43   0.03
# 6  7-Jun-22           22      0.55      0.87     0.00      1.30   0.00
#
#    adobe_acrobat  binance  samsung_internet  twitter  notifications  \
# 0            0.0     0.03              0.18     0.08            240
# 1            0.0     0.00              0.23     0.47            194
# 2            0.0     0.03              0.20     0.20            226
# 3            0.0     0.02              0.03     0.05            175
# ...

# %%
week_23 = df.iloc[7:14, :]
week_23
# Out:
#          date  week_number  facebook  whatsapp  youtube  linkedin  gmail  \
# 7    8-Jun-22           23      1.23      0.53     0.00      1.13   0.03
# 8    9-Jun-22           23      0.50      0.23     0.05      0.65   0.00
# 9   10-Jun-22           23      1.15      0.32     0.00      0.72   0.02
# 10  11-Jun-22           23      0.77      0.17     0.20      2.33   0.05
# 11  12-Jun-22           23      0.48      1.07     0.00      1.08   0.00
# 12  13-Jun-22           23      1.40      0.13     0.00      2.15   0.35
# 13  14-Jun-22           23      0.70      0.42     0.20      1.82   0.00
#
#     adobe_acrobat  binance  samsung_internet  twitter  notifications  \
# 7            0.00     0.00              0.00     0.07            297
# 8            0.00     0.02              0.08     0.15            194
# 9            0.00     0.00              0.12     0.17            207
# 10           0.00     0.03              0.33     0.37            173
# ...

# %%
week_24 = df.iloc[14:21, :]
week_24
# Out:
#          date  week_number  facebook  whatsapp  youtube  linkedin  gmail  \
# 14  15-Jun-22           24      1.27      0.30     0.08      2.07   0.12
# 15  16-Jun-22           24      1.85      0.45     0.28      1.00   0.12
# 16  17-Jun-22           24      0.68      0.18     0.00      1.45   0.05
# 17  18-Jun-22           24      1.47      0.25     0.02      2.18   0.07
# 18  19-Jun-22           24      2.00      1.42     0.52      1.12   0.22
# 19  20-Jun-22           24      2.75      1.60     1.28      1.07   0.03
# 20  21-Jun-22           24      2.05      0.62     1.03      1.83   0.08
#
#     adobe_acrobat  binance  samsung_internet  twitter  notifications  \
# 14           0.13     0.05              0.35     0.17            271
# 15           0.08     0.02              0.38     0.28            223
# 16           0.00     0.00              0.10     0.38            160
# 17           0.00     0.00              0.30     0.22            253
# ...

# %%
total_sum = df.iloc[:, 2:11].apply(pd.Series.sum)
total_sum
# Out:
# facebook            26.48
# whatsapp             9.45
# youtube              3.83
# linkedin            28.56
# gmail                1.29
# adobe_acrobat        0.23
# binance              0.35
# samsung_internet     3.46
# twitter              5.52
# dtype: float64

# %%
total_sum = total_sum.sort_values(ascending= False)
total_sum
# Out:
# linkedin            28.56
# facebook            26.48
# whatsapp             9.45
# twitter              5.52
# youtube              3.83
# samsung_internet     3.46
# gmail                1.29
# binance              0.35
# adobe_acrobat        0.23
# dtype: float64

# %%
total_sum = pd.DataFrame(total_sum)

# %%
total_sum= total_sum.reset_index()
total_sum.columns.values[0] = 'name'
total_sum.columns.values[1] = 'hours'
total_sum
# Out:
#                name  hours
# 0          linkedin  28.56
# 1          facebook  26.48
# 2          whatsapp   9.45
# 3           twitter   5.52
# 4           youtube   3.83
# 5  samsung_internet   3.46
# 6             gmail   1.29
# 7           binance   0.35
# 8     adobe_acrobat   0.23

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(total_sum['name'], total_sum['hours'], color = ['c', 'c', 'g', 'g', 'g', 'g', 'g', 'g', 'g'],
        width = 0.4)
 
plt.xlabel("App Name")
plt.ylabel("Total number of hours")
plt.title("Total Hours Spent On Social Media Apps")
plt.ylim(0,30)
plt.tight_layout()
plt.savefig('Total Hours Spent On Social Media Apps.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Visualizing the data by week

# %%
fig, axs = plt.subplots(5, 2, figsize=(14,14))
axs[0, 0].plot(week_22['date'], week_22['facebook'])
axs[0, 0].set_title('Facebook')
axs[0, 0].set_ylim([0.0, 3.0])

axs[0, 1].plot(week_22['date'], week_22['whatsapp'], 'tab:blue')
axs[0, 1].set_title('WhatsApp')

axs[1, 0].plot(week_22['date'], week_22['youtube'], 'tab:blue')
axs[1, 0].set_title('Youtube')

axs[1, 1].plot(week_22['date'], week_22['linkedin'], 'tab:blue')
axs[1, 1].set_title('Linkedin')

axs[2, 0].plot(week_22['date'], week_22['gmail'], 'tab:blue')
axs[2, 0].set_title('Gmail')

axs[2, 1].plot(week_22['date'], week_22['adobe_acrobat'], 'tab:blue')
axs[2, 1].set_title('Adobe Acrobat')

axs[3, 0].plot(week_22['date'], week_22['binance'], 'tab:blue')
axs[3, 0].set_title('Binance')

axs[3, 1].plot(week_22['date'], week_22['samsung_internet'], 'tab:blue')
axs[3, 1].set_title('Samsung Internet')

axs[4, 0].plot(week_22['date'], week_22['twitter'], 'tab:blue')
axs[4, 0].set_title('Twitter')

axs[4, 1].plot(week_22['date'], week_22['screen_time'], 'tab:blue')
axs[4, 1].set_title('Total Screen Time')


for ax in axs.flat:
    ax.set(xlabel='Date', ylabel='Time (in hours)')

plt.suptitle("Week 22 Usage Performance", size=16)
fig.tight_layout()
plt.savefig('Week 22 Usage Performance.jpeg', dpi = 300 ,  bbox_inches = "tight")

# %%
fig, axs = plt.subplots(5, 2, figsize=(14,14))
axs[0, 0].plot(week_23['date'], week_23['facebook'])
axs[0, 0].set_title('Facebook')
axs[0, 0].set_ylim([0.0, 3.0])

axs[0, 1].plot(week_23['date'], week_23['whatsapp'], 'tab:blue')
axs[0, 1].set_title('WhatsApp')

axs[1, 0].plot(week_23['date'], week_23['youtube'], 'tab:blue')
axs[1, 0].set_title('Youtube')

axs[1, 1].plot(week_23['date'], week_23['linkedin'], 'tab:blue')
axs[1, 1].set_title('Linkedin')

axs[2, 0].plot(week_23['date'], week_23['gmail'], 'tab:blue')
axs[2, 0].set_title('Gmail')

axs[2, 1].plot(week_23['date'], week_23['adobe_acrobat'], 'tab:blue')
axs[2, 1].set_title('Adobe Acrobat')

axs[3, 0].plot(week_23['date'], week_23['binance'], 'tab:blue')
axs[3, 0].set_title('Binance')

axs[3, 1].plot(week_23['date'], week_23['samsung_internet'], 'tab:blue')
axs[3, 1].set_title('Samsung Internet')

axs[4, 0].plot(week_23['date'], week_23['twitter'], 'tab:blue')
axs[4, 0].set_title('Twitter')

axs[4, 1].plot(week_23['date'], week_23['screen_time'], 'tab:blue')
axs[4, 1].set_title('Total Screen Time')


for ax in axs.flat:
    ax.set(xlabel='Date', ylabel='Time (in hours)')

plt.suptitle("Week 23 Usage Performance", size=16)
fig.tight_layout()
plt.savefig('Week 23 Usage Performance.jpeg' , dpi = 300 ,  bbox_inches = "tight")

# %%
fig, axs = plt.subplots(5, 2, figsize=(14,14))
axs[0, 0].plot(week_24['date'], week_24['facebook'])
axs[0, 0].set_title('Facebook')
axs[0, 0].set_ylim([0.0, 3.0])

axs[0, 1].plot(week_24['date'], week_24['whatsapp'], 'tab:blue')
axs[0, 1].set_title('WhatsApp')

axs[1, 0].plot(week_24['date'], week_24['youtube'], 'tab:blue')
axs[1, 0].set_title('Youtube')

axs[1, 1].plot(week_24['date'], week_24['linkedin'], 'tab:blue')
axs[1, 1].set_title('Linkedin')

axs[2, 0].plot(week_24['date'], week_24['gmail'], 'tab:blue')
axs[2, 0].set_title('Gmail')

axs[2, 1].plot(week_24['date'], week_24['adobe_acrobat'], 'tab:blue')
axs[2, 1].set_title('Adobe Acrobat')

axs[3, 0].plot(week_24['date'], week_24['binance'], 'tab:blue')
axs[3, 0].set_title('Binance')

axs[3, 1].plot(week_24['date'], week_24['samsung_internet'], 'tab:blue')
axs[3, 1].set_title('Samsung Internet')

axs[4, 0].plot(week_24['date'], week_24['twitter'], 'tab:blue')
axs[4, 0].set_title('Twitter')

axs[4, 1].plot(week_24['date'], week_24['screen_time'], 'tab:blue')
axs[4, 1].set_title('Total Screen Time')


for ax in axs.flat:
    ax.set(xlabel='Date', ylabel='Time (in hours)')

plt.suptitle("Week 24 Usage Performance", size=16)
fig.tight_layout()
plt.savefig('Week 24 Usage Performance.jpeg', dpi = 300 ,  bbox_inches = "tight")

# %% [markdown]
# ### 👉 Visualizing the data by all week

# %%
# Facebook All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['facebook'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['facebook'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['facebook'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Facebook Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,3)
plt.legend()
plt.tight_layout()
plt.savefig('Facebook Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# WhatsApp All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['whatsapp'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['whatsapp'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['whatsapp'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("WhatsApp Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,1.8)
plt.legend()
plt.tight_layout()
plt.savefig('WhatsApp Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Youtube All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['youtube'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['youtube'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['youtube'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Youtube Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(-0.02,.4)
plt.legend()
plt.tight_layout()
plt.savefig('Youtube Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Linkedin All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['linkedin'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['linkedin'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['linkedin'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Linkedin Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,2.5)
plt.legend()
plt.tight_layout()
plt.savefig('Linkedin Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Gmail All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['gmail'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['gmail'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['gmail'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Gmail Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(-0.02,0.4)
plt.legend()
plt.tight_layout()
plt.savefig('Gmail Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Adobe Acrobat All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['adobe_acrobat'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['adobe_acrobat'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['adobe_acrobat'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Adobe Acrobat Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(-0.01,0.15)
plt.legend()
plt.tight_layout()
plt.savefig('Adobe Acrobat Usage.jpg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Binance All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['binance'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['binance'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['binance'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Binance Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(-0.0035,0.06)
plt.legend()
plt.tight_layout()
plt.savefig('Binance Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Samsung Internet All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['samsung_internet'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['samsung_internet'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['samsung_internet'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Samsung Internet Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(-0.02,0.45)
plt.legend()
plt.tight_layout()
plt.savefig('Samsung Internet Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Twitter All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['twitter'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['twitter'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['twitter'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Twitter Usage")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,1.25)
plt.legend()
plt.tight_layout()
plt.savefig('Twitter Usage.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Notifications All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['notifications'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['notifications'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['notifications'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Total Notifications")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,425)
plt.legend()
plt.tight_layout()
plt.savefig('Total Notifications.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Screen time All Weeks

plt.figure(figsize=(10, 5))
plt.scatter(week_22['date'], week_22['screen_time'], c ="orange",
            linewidths = 2,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['date'], week_23['screen_time'], c ="royalblue",
            linewidths = 2,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['date'], week_24['screen_time'], c ="red",
            linewidths = 2,
            s = 100, label= '(Week 24)')

plt.title("Total Screen Time")
plt.xlabel("Date")
plt.ylabel("Time (in hours)")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,10)
plt.legend()
plt.tight_layout()
plt.savefig('Total Screen Time.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %%
# Most Notifications App All Weeks

plt.figure(figsize=(9, 6))
plt.scatter(week_22['most_notifications_app'], week_22['date'], c ="orange",
            linewidths = 1,
            s = 100, label= '(Week 22)')
 
plt.scatter(week_23['most_notifications_app'], week_23['date'], c ="royalblue",
            linewidths = 1,
            s = 100, label= '(Week 23)')

plt.scatter(week_24['most_notifications_app'], week_24['date'], c ="red",
            linewidths = 1,
            s = 100, label= '(Week 24)')

plt.title("Most Notifications App")
plt.xlabel("Applications")
plt.ylabel("Date")
plt.legend()
plt.tight_layout()
plt.savefig('Most Notifications App.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Percentage of each app usage of 3 weeks

# %%
total_hours = total_sum['hours'].sum()
total_hours
# Out:
# 79.17

# %%
total_sum['percentage'] = total_sum.hours / total_hours.sum()
total_sum
# Out:
#                name  hours  percentage
# 0          linkedin  28.56    0.360743
# 1          facebook  26.48    0.334470
# 2          whatsapp   9.45    0.119363
# 3           twitter   5.52    0.069723
# 4           youtube   3.83    0.048377
# 5  samsung_internet   3.46    0.043703
# 6             gmail   1.29    0.016294
# 7           binance   0.35    0.004421
# 8     adobe_acrobat   0.23    0.002905

# %%
plt.figure(figsize=(10, 5))
colors = ['#0077b5', '#3b5998', '#43d854', '#55acee', '#cd201f', 'b', '#ea4335', '#F3BA2F', 'r']
plt.barh(total_sum['name'], total_sum['percentage'], color= colors)
plt.title("Percentage of total usage")
plt.xlabel("Percentage")
plt.ylabel("Application Name")
plt.tight_layout()
plt.savefig('Percentage of total usage.jpeg' , dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Total number of Notifications

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(df['date'], df['notifications'], color = 'slateblue',
        width = 0.4)
 
plt.xlabel("Date")
plt.ylabel("Total number of notifications")
plt.title("Total Notifications of Social Media Apps")
plt.xticks(rotation=90, fontweight='medium',  fontsize='medium')
plt.ylim(0,400)
plt.tight_layout()
plt.savefig('Total Notifcations of Social Media Apps.jpeg', dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Most Notifications App Count

# %%
plt.figure(figsize=(10, 5))
ax = sns.countplot(data=df, y='most_notifications_app')
plt.title("Most Notifications App Count", size=16)
plt.ylabel('Apps')
plt.tight_layout()
plt.savefig('Most notifications app count.jpeg' , dpi = 300 ,  bbox_inches = "tight")
plt.show()

# %% [markdown]
# ### 👉 Heatmap of Social Media apps usage

# %%
fig, ax = plt.subplots(figsize=(11, 7))
sns.heatmap(df.iloc[:, 2:11].corr(), vmin=-1, vmax=1,
annot=True,cmap="rocket_r")
title = 'Correlation of all columns'.upper()
plt.title(title, loc='center')
plt.tight_layout()
plt.savefig('Correlation of all columns.jpg', dpi = 300 ,  bbox_inches = "tight")
plt.show()
